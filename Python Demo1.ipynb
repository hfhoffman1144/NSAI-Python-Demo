# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Data Processing and Analysis with Pandas

# %%
pd.pandas.set_option("display.max_columns",None)
pd.set_option('use_inf_as_na', True)

# %%
# Read in dataset
data = pd.read_excel("../2020.07.06 WellHeaderData.xlsx")

# Print data dimenstions (number of rows, number of columns)
print(data.shape)

# View the first few rows of the dataset
data.head()
# Out:
# (4749, 58)
#    LINE  NUMBER SOURCE Source Number Last Updated Op vs NonOp           API14  \
# 0     1       8     DI        000008   2020-03-31       NONOP  17017342380000
# 1     2       9     DI        000009   2020-03-31       NONOP  17017342570000
# 2     3      11     DI        000011   2020-03-31       NONOP  17017342970000
# 3     4      12     DI        000012   2020-03-31       NONOP  17017343140000
# 4     5      13     DI        000013   2020-03-31       NONOP  17017343150000
#
#           API12         API   PetraMidX    PetraMidY  RESCAT  \
# 0  170173423800  1701734238  1337858.35  11748405.60   11000
# 1  170173425700  1701734257  1355135.90  11743370.20   11000
# 2  170173429700  1701734297  1372326.50  11753768.00   11000
# 3  170173431400  1701734314  1335205.15  11711505.20   11000
# 4  170173431500  1701734315  1360611.40  11711118.75   11000
#
#                NAME               FIELD COUNTY  ST    OPERATOR    RESERVOIR  \
# 0  MARTIN ROY 23H 1    GREENWOOD-WASKOM  CADDO  LA  CHESAPEAKE  HAYNESVILLE
# 1      SRLT 29 2ALT      JOHNSON BRANCH  CADDO  LA  CHESAPEAKE  HAYNESVILLE
# 2    CHIGGERO 14H 1             METCALF  CADDO  LA  CHESAPEAKE  HAYNESVILLE
# 3        BRAY 27H 1  BETHANY LONGSTREET  CADDO  LA  CHESAPEAKE  HAYNESVILLE
# 4          FEIST 28            CASPIANA  CADDO  LA  CHESAPEAKE  HAYNESVILLE
#
#    ELEVATION (KB)  ELEVATION (GROUND)       TVD      LL       LBS/FT  \
# 0          289.12              265.12  11484.00  4062.0   659.211144
# 1          275.56              247.56  11706.00  4224.0   352.000000
# 2          195.00              181.00  14550.00  3049.0  2957.976243
# 3          339.00              311.00  11412.19  4027.0     0.000000
# 4          280.00              252.00  11596.56  3687.0   496.000000
#
#       FPDATE  FP YEAR  GAS EUR (MCF)  OIL EUR (BBL)       NWC  2018 NWC  \
# 0 2008-07-01   2008.0   2.106648e+06            0.0  1.480434  1.524879
# 1 2007-10-01   2007.0   1.165165e+06           24.0  0.998251  0.971432
# 2 2008-07-01   2008.0   6.184459e+06            0.0  0.766312  0.737059
# 3 2008-09-01   2008.0   1.398889e+06            0.0  2.221564  1.944644
# 4 2008-01-01   2008.0   2.010094e+06            0.0  2.953830  3.056816
#
#    2017 NWC  2016 NWC  2015 NWC  2014 NWC  2013 NWC  2012 NWC  2011 NWC  \
# 0  1.524879  1.524879  1.524879  1.417210  1.417210  1.417210  1.409923
# 1  0.971432  0.971432  0.971432  0.953708  0.953708  0.953708  0.994635
# 2  0.737059  0.737059  0.737059  0.731659  0.731659  0.731659  0.774552
# 3  1.622499  1.622499  1.622499  1.655913  1.655913  1.655913  1.659251
# 4  2.301864  2.301864  2.301864  2.326322  2.326322  1.538302  1.540305
#
#    2010 NWC  2009 NWC  2008 NWC  As Drilled NWC  Years Until NWC Change  \
# 0  1.423519  1.418701  0.814100        0.814100                     1.0
# 1  0.993574  0.955759  0.843008        0.843008                     NaN
# 2  0.754649  0.727722  0.595234        0.595234                     NaN
# 3  1.658169  0.822942  0.842586        0.842586                     2.0
# 4  1.497429  1.510324  1.504753        1.504753                     5.0
#
#    SH Latitude  SH Longitude  BH Latitude  BH Longitude  \
# 0    32.369389    -93.979988    32.356873    -93.980389
# 1    32.345797    -93.918437    32.354143    -93.930474
# 2    32.374421    -93.868364    32.374421    -93.868364
# 3    32.255658    -93.987770    32.267620    -93.987793
# 4    32.255444    -93.905791    32.267173    -93.905731
#
#    Net to Gross (4% Phi Cutoff)  Net to Gross (8% Phi Cutoff)  \
# 0                          0.86                          0.60
# 1                          0.94                          0.73
# 2                          0.93                          0.63
# 3                          0.91                          0.48
# 4                          0.96                          0.66
#
#    OGIP (4% Phi Cutoff)  OGIP (8% Phi Cutoff)  OGIP/GT (4% Phi Cutoff)  \
# 0                162.57                120.99                 0.696714
# 1                140.76                118.00                 0.703701
# 2                134.09                104.22                 0.658588
# 3                159.07                105.85                 0.685141
# 4                147.49                112.38                 0.696521
#
#    OGIP/GT (8% Phi Cutoff)    EUR/Ft  DI Practical IP  DI Gas Daily Rate  \
# 0                 0.519181   518.623        2789.2903           376.9691
# 1                 0.587445   275.844        2172.9667           208.1233
# 2                 0.511459  2028.357        4455.3548           907.5027
# 3                 0.455759   347.378        2196.2903           267.2334
# 4                 0.531071   545.184         252.1379           390.9984
#
#    DI 1 Month Gas  DI 6 Month CUM  DI 12 Month CUM  DI First Test Gas Volume
# 0        123817.0        390459.0         490004.0                    3979.0
# 1         55393.0        263211.0         348610.0                    2647.0
# 2         54307.0        511717.0         718823.0                    4634.0
# 3         63926.0        290997.0         426304.0                    3720.0
# 4         53833.0        418617.0         736836.0                    2645.0
